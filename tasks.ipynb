# %% [markdown]
# # Fundamentals of Data Analysis Tasks
#
# ** Audrey Allen **

# %% [markdown]
# # Task 1 - The Collatz Conjecture
#
# The Collatz conjecture1 is a famous unsolved problem in mathematics. The problem is to prove that if you start with any positive
# integer x and repeatedly apply the function f (x) below, you always
# get stuck in the repeating sequence 1, 4, 2, 1, 4, 2, . . .
#
# x ÷ 2 if x is even
# 3x + 1 otherwise
# For example, starting with the value 10, which is an even number,
# we divide it by 2 to get 5. Then 5 is an odd number so, we multiply
# by 3 and add 1 to get 16. Then we repeatedly divide by 2 to
# get 8, 4, 2, 1. Once we are at 1, we go back to 4 and get stuck in the
# repeating sequence 4, 2, 1 as we suspected.
# Your task is to verify, using Python, that the conjecture is true for
# the first 10,000 positive integers.

# %% [markdown]
# Firstly we define a function. If x is even we divide by 2.
# Otherwise we multiply by 3 and add 1.

# %%
def f(x):
    # If x is even divide it by 2
    if x % 2 == 0:
        return x // 2
    else:
        return (3 * x)   + 1

# %% [markdown]
# A second function called collatz passing in the value of x until x = 1. The collatz function called the f function while x not equal to 1. When x = 1 the program ends.

# %%
def collatz(x):
    collatz.counter = 0
    while x != 1:
         print(x, end=',  ')
         x=f(x)
         collatz.counter += 1
    print(x)

    if x == 1:
     print ("The Collatz Conjecture works with this number!")
    else: 
     ("This number does NOT work with the Collatz Conjecture!") 

     collatz.counter = 0

# %% [markdown]
# The below piece of code calls the collatz function by passing in the number in brackets to the function. This value is x.

# %%
collatz(10000)
# Out:
# 10000,  5000,  2500,  1250,  625,  1876,  938,  469,  1408,  704,  352,  176,  88,  44,  22,  11,  34,  17,  52,  26,  13,  40,  20,  10,  5,  16,  8,  4,  2,  1
# The Collatz Conjecture works with this number!

# %% [markdown]
# ***
#
# # End Task 1

# %% [markdown]
# # Task 2
# Give an overview of the famous penguins data set, explaining
# the types of variables it contains. Suggest the types of variables
# that should be used to model them in Python, explaining your
# rationale.
#
# ### Overview of the Penguins Dataset
# ![image.png](attachment:image.png)
#
# The Penguins dataset was collected between 2007–2009 by Dr. Kristen Gorman with the Palmer Station Long Term Ecological Research Program, part of the US Long Term Ecological Research Network.
#
# The palmerpenguins data contains size measurements for three penguin species observed on three islands in the Palmer Archipelago, Antarctica. The Penguins dataset has 7 columns and 344 rows. Of the 7 columns 3 are categorical (species, island, sex) and the rest are numeric (bill_length_mm	bill_depth_mm	flipper_length_mm	body_mass_g).
#
# ![image-2.png](attachment:image-2.png)
#
# ### Description of Columns in Penguins Dataset
# 1. species - Field denoting the penguin species(Adelie, Gentoo, and Chinstrap)
# 2. island - Field denoting the island in Palmer Archipelago
# 3. bill_length_mm - a number denoting the bill length of the penguin in millimeters
# 4. bill_depth_mm - a number denoting the bill depth of the penguin in millimeters
# 5. flipper_length_mm - a number denoting the flipper length of the penguin in millimeters
# 6. body_mass_g - a number denoting body mass in grams
# 7. sex - Field denoting penguin sex (female, male)
#
# ### Type of Variable
#
# 1. species - categorical
# 2. island -  categorical
# 3. bill_length_mm - numerical
# 4. bill_depth_mm - numerical
# 5. flipper_length_mm - numerical
# 6. body_mass_g - numerical
# 7. sex - categorical
#
# ### What are the types of variables in a dataset?
# Variables may be classified into two main categories: qualitative or categorical and quantitative or numeric. Each category is then classified in two subcategories: nominal or ordinal for categorical variables, discrete or continuous for numeric variables.
#
# ### What is a qualitative or categorial variable in the Penguins Dataset?
#
# A categorical variable is one that has two or more categories, but there is no intrinsic ordering to the categories. There are two classifications of categorical data: nominal and ordinal. The categorical variables in the Penguins dataset are nominal variables. (Not ordered) Categorical variables represent groups. The 3 categorical variables in this dataset have a limited number of values and these are very useful in statistical modelling. There are both dependant and independant variables in modelling. Species is the only dependant variable in this dataset. The other 6 are independant variables. Dependant variables are also known as response variables they respond to changes in another variable. (Independant Variable).
#
# ### What is a quantitative  variable in the Penguins Dataset?
#
# Quantitative variables are any variables where the data represent amounts. There are 4 quantitative variables in the Penguin Dataset, bill_length_mm, bill_depth_mm,flipper_length_mm and body_mass_g. The 4 variables are also known as 'Continuous  variables'. This means that the variables have got their value by measuring or weighing.
#
# ### What type of variable should be used to model the Penguins dataset in python?
#
# In order to perform useful analysis and regression analyis on the penguins dataset it is important that we have both qualitative and quantitative variables to work with. I think for this reason it is appropriate to have the 4 variables as numerical, continuous variables (as per graphic above). A Point to remember is that continuous variables can potentially take on a infinite number of values. There are two types of continuous variable
#
# 1. Ratio - Has a defined zero point
# 2. Interval - Does not have a defined zero point. An example of this would be time.
#
# The type of continuous variable in the Penguins dataset is a ratio variable. e.g. bill_length_mm, bill_depth_mm, flipper_length_mm and body_mass_g. All of these values have a zero starting point. They are categorised correctly using these variable types. You cannot have a penguin that has a minus body mass for example. The starting point for all of the numerical variables is 0.
#
# Regression analysis is used when you try to find a relationship between varibles. In Python using a correlation matrix and also utilisation of scatterplots to visualise the possible relationship between two or more of the variables. The penguin dataset is similar to the iris dataset in the fact that there are 4 numerical fields. 3 of these are measurements and 1 is the weight of the penguin. It differs to Iris in the fact that there are two more categorical variables in addition to species and these are sex and island.
#
# We can perform both classification and regression analysis on this dataset. With classification the target variable (A target variable is the feature of a dataset that you want to understand more clearly.) The variable you want to predict is categorical. We can use this dataset to predict the penguins species from the anatomical information we are given such as the measurements and weight of the penguin.
#
# See below piece of code where by graphing the bill lenth and depth we can guess the species.

# %%
#Author: Audrey Allen

import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
  

# Read in CSV file

penguins  = pd.read_csv('Data/penguins.csv')

# The code below outputs all of the variables and the variable type
# As you can see from the code below Pandas call the strings 'object' 
# and the numberic fields 'float64'

penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# The below piece of code outputs a scatterplot using the two numeric fields so that the
# type of penguin species can be distinguished in Python

sns.set_style('white')
sns.FacetGrid(penguins, hue ="species")\
   .map(plt.scatter,"bill_length_mm","bill_depth_mm")\
   .add_legend();
plt.show()

# %% [markdown]
# We can see from the above scatterplot that using the bill length and depth we can distinguish the Adelie species.  Chinstrap and Gentoo are slightly harder to distinguish as there is some overlap.

# %% [markdown]
# ### Conclusion Task 2
#
# ### Data Type
#
# As we have seen above the pandas datatypes for the penguin dataset are comprised of two variable types. See below for the breakdown.
#
# #### Pandas Variable Type Breakdown
#
# 1. Object - for the Categorical variables - species, island and sex
# 2. float64 - for the variables bill_length_mm  bill_depth_mm flipper_length_mm and body_mass_g
#
#
# #### Python Variable Type Breakdown
#
# 1. species, island and sex - These categorical variables shouldd be modelled in python using string as they contain text values.
# 2. bill_length_mm  bill_depth_mm - These numerical floating point variables should be modelled in Python as floats as these are precision variables and contain a decimal point.
# 3. flipper_length_mm  body_mass_g -  These numerical floating point variables should be modelled in Python as integers as they do not have a decimal point.

# %% [markdown]
# ***
#
# ### End Task 2
#
# References Task 2
#
# https://stats.oarc.ucla.edu/other/mult-pkg/whatstat/what-is-the-difference-between-categorical-ordinal-and-interval-variables/
#
# https://en.wikipedia.org/wiki/Continuous_or_discrete_variable
#
# https://www.cvent.com/en/blog/events/data-types-interval-ratio-data#:~:text=Ratio%20data%20has%20a%20defined,are%20examples%20of%20ratio%20data.
#
# https://www.kaggle.com/code/parulpandey/penguin-dataset-the-new-iris
#
# https://en.wikipedia.org/wiki/Level_of_measurement

# %% [markdown]
# ### Task 3
#
# For each of the variables in the penguins data set, suggest what probability distribution from the numpy random distributions list is the most appropriate to model the variable.
#
# What is Probability Distribution?
#
# A probability distribution is a statistical function that describes all the possible values and probabilities for a random variable within a given range.
#
# The palmerpenguins data contains size measurements for three penguin species observed on three islands in the Palmer Archipelago, Antarctica. The Penguins dataset has 7 columns and 344 rows. Of the 7 columns 3 are categorical (species, island, sex) and the rest are numeric (bill_length_mm	bill_depth_mm	flipper_length_mm	body_mass_g).
#
# species - Categorical variable
#
# Firstly we need to find out what the actual distribution is for this species variable. There are a few ways we can do this.
#
# In order to summarize the distribution of a categorical variable, we first create a table of the different values (categories) the variable takes, how many times each value occurs (count) and, more importantly, how often each value occurs (by converting the counts to percentages).
#
# I will demonstrate this by firstly doing a frequency chart for the series variable and then a bar chart.

# %%
# Firstly I import the pandas package to read the Data/penguins.csv file

import pandas as pd

# Read in CSV file

penguins  = pd.read_csv('Data/penguins.csv')

# The below piece of code counts how many times each species appears in the dataset 

df = penguins['species'].value_counts() 
print(df) 

# What we can see from the frequency distribution below is that the Adelie species appears the most times in the dataset and Chinstrap 
# the least amount of times
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
import pandas as pd

# Read in CSV file

penguins  = pd.read_csv('Data/penguins.csv')

# one way frequency table for the species column. 
freq_table = pd.crosstab(penguins['species'], 'no_of_species') 
  
# frequency table in proportion of species 
freq_table= freq_table/len(penguins) 
  
freq_table 

# The below frequency table shows the proportion of the total of that species appears in the dataset. This is a just a different
# representation of the frequency table above
# Below we show that Adelie occurs most frquently in the dataset, then Gentoo species and finally Chinstrap occurs the least
# amount of times in the dataset
# Out:
# col_0      no_of_species
# species
# Adelie          0.441860
# Chinstrap       0.197674
# Gentoo          0.360465

# %%
import pandas as pd
import seaborn as sns    
import matplotlib.pyplot as plt

penguins  = pd.read_csv('Data/penguins.csv')

sns.countplot(x='species',data=penguins)
plt.title('Frequency of Three Species')
# giving X and Y labels
plt.xlabel("Species")
plt.ylabel("Count")
plt.legend(['All Species'])
plt.show()

# %% [markdown]
# The numpy function numpy.random.choice generates a random sample from a 1-D array such as a categorical variable like species type. There are a number of parameters with this function.
#
#  random.choice(a, size=None, replace=True, p=None)
#
#  1. Array
#  2. How many records you want in the sample array
#  3. replace = True - Whether the sample is with or without replacement. Default is True, meaning that a value of a can be selected multiple times.
#  4. Probabilities of each entry - We have the probability of each value as we calculated this above in the frequency table. If we do not specify this a uniform distribution is assumed.
#
#  The probability must add up to 1
#
#  The  distribution of the species variable is multinomial - This is a common distribution for characterizing categorical variables. This means that there is a possibility of two or more different results.

# %%
# You can see that I have entered the frequency distribution for the species variable that I have calculated below
# 0.44 for Adelie, 0.2 for Chinstrap and 0.36 for Gentoo

# Probability distribution for the variable species
import numpy as np

penguin_arr = ['Adelie', 'Chinstrap', 'Gentoo']
np.random.choice(penguin_arr, 1000, p=[0.44, 0.2, 0.36])
# Out:
# array(['Gentoo', 'Chinstrap', 'Adelie', 'Adelie', 'Gentoo', 'Gentoo',
#        'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Chinstrap', 'Chinstrap', 'Adelie', 'Chinstrap',
#        'Chinstrap', 'Gentoo', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Gentoo', 'Gentoo', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie',
#        'Adelie', 'Chinstrap', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Gentoo', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Adelie', 'Gentoo', 'Gentoo', 'Chinstrap', 'Chinstrap',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Chinstrap', 'Adelie', 'Adelie', 'Chinstrap',
#        'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Adelie',
# ...

# %% [markdown]
# The  distribution of the island variable is multinomial - This is a common distribution for characterizing categorical   variables. This means that there is a possibility of two or more different results.
#
# There are three islands Torgersen, Dream and Biscoe.

# %%
import pandas as pd

# Read in CSV file

penguins  = pd.read_csv('Data/penguins.csv')


df = penguins['island'].value_counts() 
print(df) 


# one way frequency table for the species column. 
freq_table = pd.crosstab(penguins['island'], 'no_of_islands') 
  
# frequency table in proportion of species 
freq_table= freq_table/len(penguins) 
  
freq_table 


# We can see from the two frequency tables below which the amount of times each island appears in the dataset. The second 
# frequency table shows the proportion of the total of that islands appears in the dataset. This is a just a different
# representation of the frequency table above
# Below we show that Biscoe occurs most frquently in the dataset, then Dream species and finally Torgersen      occurs the least
# amount of times in the dataset
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64
# col_0      no_of_islands
# island
# Biscoe          0.488372
# Dream           0.360465
# Torgersen       0.151163

# %%
import pandas as pd
import seaborn as sns    
import matplotlib.pyplot as plt

penguins  = pd.read_csv('Data/penguins.csv')

# I have output a bar chart to visualise the distribution of the island variable

sns.countplot(x='island',data=penguins)
plt.title('Frequency of Three Islands')
# giving X and Y labels
plt.xlabel("Islands")
plt.ylabel("Count")
plt.legend(['All Islands'])
plt.show()

# %% [markdown]
# Again similar to the species variable the numpy function numpy.random.choice would be the best probability distribution from the
# numpy random distributions list that I would choose for the categorical variable island.
#
# The numpy function numpy.random.choice generates a random sample from a 1-D array such as a categorical variable like island.
#
# random.choice(a, size=None, replace=True, p=None)
#
# We have calculated the  probability above and will use it for this function. Remember The probability must add up to 1
#
# The distribution of the island variable is multinomial - This is a common distribution for characterizing categorical variables. This means that there is a possibility of two or more different results.

# %%
# You can see that I have entered the frequency distribution for the island variable that I have calculated previously
# 0.49 for Biscoe, 0.36 for Dream and 0.15 for Torgensen

# Probability distribution for variable 'island'

import numpy as np

penguinisland_arr = ['Biscoe', 'Dream', 'Torgersen']
penguinisland = np.random.choice(penguinisland_arr, 1000, p=[0.49, 0.36, 0.15])

print(penguinisland)
# Out:
# ['Biscoe' 'Dream' 'Biscoe' 'Torgersen' 'Torgersen' 'Biscoe' 'Dream'
#  'Torgersen' 'Torgersen' 'Biscoe' 'Biscoe' 'Biscoe' 'Biscoe' 'Dream'
#  'Torgersen' 'Biscoe' 'Torgersen' 'Biscoe' 'Biscoe' 'Torgersen' 'Biscoe'
#  'Torgersen' 'Torgersen' 'Biscoe' 'Dream' 'Biscoe' 'Torgersen' 'Dream'
#  'Dream' 'Biscoe' 'Dream' 'Biscoe' 'Biscoe' 'Biscoe' 'Biscoe' 'Dream'
#  'Torgersen' 'Torgersen' 'Dream' 'Dream' 'Torgersen' 'Biscoe' 'Biscoe'
#  'Dream' 'Biscoe' 'Torgersen' 'Biscoe' 'Dream' 'Dream' 'Biscoe' 'Biscoe'
#  'Torgersen' 'Dream' 'Biscoe' 'Dream' 'Torgersen' 'Biscoe' 'Biscoe'
#  'Biscoe' 'Dream' 'Dream' 'Biscoe' 'Dream' 'Dream' 'Biscoe' 'Biscoe'
#  'Biscoe' 'Biscoe' 'Biscoe' 'Dream' 'Dream' 'Torgersen' 'Dream' 'Dream'
#  'Dream' 'Dream' 'Torgersen' 'Biscoe' 'Torgersen' 'Dream' 'Dream'
#  'Torgersen' 'Biscoe' 'Biscoe' 'Biscoe' 'Dream' 'Dream' 'Dream' 'Dream'
#  'Dream' 'Dream' 'Biscoe' 'Biscoe' 'Biscoe' 'Dream' 'Torgersen' 'Biscoe'
# ...

# %%
# Histogram using the function random.choice function

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10, 5))
plt.hist(penguinisland,5, histtype='bar', stacked=True)
plt.title("Penguin Island")
plt.xlabel("Penguin Island")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.xlabel("Penguin Island", fontsize=10)
plt.xticks(fontsize=10)
plt.savefig('Images/Penguin Island.png')# Save to PNG file in the Images folder
plt.show()

# %% [markdown]
# Similar to the species variable the numpy function numpy.random.choice would be the best probability distribution from the
# numpy random distributions list that I would choose for the categorical variable sex.
#
#
# The distribution of the island variable is binomial - This is a distribution that only has two outcomes such as the variable sex. The outcome can either be 'male' or 'female'.
#
# Firstly we will get the distribution of the variable 'sex'.

# %%
import pandas as pd

# Read in CSV file

penguins  = pd.read_csv('Data/penguins.csv')


df = penguins['sex'].value_counts() 
print(df) 


# one way frequency table for the species column. 
freq_table = pd.crosstab(penguins['sex'], 'Count_of_Sex') 
  
# frequency table in proportion of species 
freq_table= freq_table/len(penguins) 
  
freq_table 

# We can see from the two frequency tables below that both male and female sex appears equal in the dataset. Approx 0.5 male 
# 0.5 female. We can use this for the nump.choice random distribution that we will use for this variable.
# Out:
# MALE      168
# FEMALE    165
# Name: sex, dtype: int64
# col_0   Count_of_Sex
# sex
# FEMALE      0.479651
# MALE        0.488372

# %%
# Similar to the categorical variables above I can create a bar chart to plot the distribution of the 'sex' variable'

import pandas as pd
import seaborn as sns    
import matplotlib.pyplot as plt

penguins  = pd.read_csv('Data/penguins.csv')

sns.countplot(x='sex',data=penguins)
plt.title('Frequency of Sex')
# giving X and Y labels
plt.xlabel("sex")
plt.ylabel("Count")
plt.legend(['Male and Female'])
plt.show()

# I have output a bar chart to visualise the distribution of the island variable

# %%
# To Calculate the probability distribution of the sex variable we will us np.random.choice
# You can see that I have entered the frequency distribution for the sex variable that I have calculated previously
# 0.5 for Male, 0.5 for Female 

# Probability distribution for variable 'island'

import numpy as np
import matplotlib.pyplot as plt

penguin_sex = ['Male', 'Female']
Penguinsex = np.random.choice(penguin_sex, 1000, p=[0.5, 0.5])

print (Penguinsex)
# Out:
# ['Male' 'Male' 'Female' 'Female' 'Male' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Male' 'Male' 'Male' 'Male'
#  'Male' 'Male' 'Female' 'Male' 'Female' 'Male' 'Female' 'Female' 'Male'
#  'Male' 'Male' 'Female' 'Female' 'Male' 'Male' 'Female' 'Female' 'Female'
#  'Male' 'Female' 'Female' 'Male' 'Female' 'Female' 'Male' 'Male' 'Male'
#  'Male' 'Male' 'Female' 'Female' 'Male' 'Female' 'Female' 'Male' 'Female'
#  'Female' 'Male' 'Female' 'Female' 'Male' 'Female' 'Male' 'Male' 'Male'
#  'Male' 'Female' 'Female' 'Male' 'Female' 'Male' 'Female' 'Male' 'Male'
#  'Female' 'Female' 'Male' 'Male' 'Male' 'Male' 'Male' 'Male' 'Male' 'Male'
#  'Male' 'Female' 'Female' 'Female' 'Male' 'Male' 'Male' 'Female' 'Female'
#  'Female' 'Male' 'Female' 'Male' 'Female' 'Female' 'Male' 'Male' 'Female'
#  'Female' 'Male' 'Female' 'Female' 'Male' 'Male' 'Male' 'Male' 'Male'
#  'Male' 'Male' 'Female' 'Male' 'Male' 'Female' 'Female' 'Male' 'Male'
# ...

# %% [markdown]
# I am going to create a histogram for the simulated Penguin sex variable. The frequency table shows us the frequency distribution which can be a parameter for the random.choice function.

# %%
# Histogram using the function random.choice function

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10, 5))
plt.hist(Penguinsex,3, histtype='bar', stacked=True)
plt.title("Penguin Sex")
plt.xlabel("Penguin Sex")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.xlabel("Penguin Sex", fontsize=10)
plt.xticks(fontsize=15)
plt.savefig('Images/Penguin Sex.png')# Save to PNG file in the Images folder
plt.show()

# %% [markdown]
# The next 4 variables that I will be looking at in regards to probability  distribution from the numpy random distributions list are the 4 numerical variables ,bill_length_mm,bill_depth_mm,flipper_length_mm and body_mass_g
#
# 1. bill_length_mm
# 2. bill_depth_mm
# 3. flipper_length_mm
# 4. body_mass_g
#
# 1. bill_length_mm - I am going to model the bill_length_mm for one species on a histogram to see if the distribution is normal.

# %%
#billlength - Histogram - see if the distribution is normal
import pandas as pd
import matplotlib.pyplot as plt

penguins  = pd.read_csv('Data/penguins.csv')


plt.figure(figsize = (10, 5))
x =[penguins.bill_length_mm[penguins.species==sp_name] for sp_name in ['Gentoo']]
plt.hist(x,20, histtype='bar', stacked=True)
plt.legend(['Gentoo'])
plt.title("bill_length_mm for Gentoo Species")
plt.xlabel("bill_length_mm")
plt.ylabel("Count")
plt.savefig('Images/bill_length_mm.png')# Save to PNG file
plt.show()



# We can tell from the distribution on the bill length that the distribution is not normal for the Gentoo species of penguin. i.e. it is not symetrical or in a 
# bell curve shape. I can see there are outliers on the right hand side of the histogram which leads me to think that the data is 
# skewed. It is a right skewed distribution as the tail is on the right hand side.

# %% [markdown]
# The Numpy probability distribution that I would use for the variable bill length would be np.random.gamma.
#
# This function seems to fit the probability distribution for bill length. It is the closest match of the distributions that I could find.
#
# Gamma Distribution - The Gamma Distribution is a 2 parameter family of continuous probability distributions. I can see below that the histogram produced by the random.gamma command is similar to the histogram for bill length in the Gentoo species.
#
# The histogram for bill length is also multimodal which means that it has more than one peak.

# %%
# import numpy and gamma 
import numpy as np 
import matplotlib.pyplot as plt 
  
# Using gamma() method 
gfg = np.random.gamma(3, 20, 100) 

print (gfg)
  
count, bins, ignored = plt.hist(gfg, 14, density = True) 
plt.title('Gamma Distribution for Bill Length')
plt.xlabel("bill_length_mm")
plt.ylabel("Count")
plt.show()
# Out:
# [113.19562188  43.11911732  48.42790326  23.57476188  54.20926248
#   87.64919778  36.17045783  56.04426947  85.01242772  87.0781745
#   46.05805167  57.64249711  52.96852058  48.00575599  81.1814287
#   18.37339044  76.72336642  68.29701686  57.67649625  68.87264324
#   31.34585301  35.9240072  100.53834354  61.23915027  65.76986989
#   48.93174463  12.03276976  49.43323381  47.75991308  62.80706762
#   58.06984756 120.55211933  18.14110309  41.83917701  50.46714179
#   44.90322692  16.26470216  38.60709097  54.55792223  31.22786655
#   25.13636815  41.39251562  78.91535998  64.82465282  57.72661673
#   37.451892    23.4131151   34.40524903 137.79531149   9.12074643
#   47.42262984  90.69993108  55.10887644  27.17840408   4.30520837
#   55.07132014  62.06759801  47.85105306  85.42304644  91.12199963
#   41.26989176  48.65072786 148.29223781  23.0887352   15.40652005
#   19.70852143  45.89492171  32.73944668  44.39358025  85.59126759
# ...

# %% [markdown]
# 2. bill_depth_mm - I am going to model the bill_length_mm for one species on a histogram to see if the distribution is normal.
#
# The  variable bill depth is a continuous random variable. I am going to plot the data on a histogram to see what the distribution looks like. For this example I will again pick the Gentoo species.

# %%
#billdepth - Histogram - see if the distribution is normal
import pandas as pd
import matplotlib.pyplot as plt

penguins  = pd.read_csv('Data/penguins.csv')


plt.figure(figsize = (10, 5))
x =[penguins.bill_depth_mm[penguins.species==sp_name] for sp_name in ['Gentoo']]
plt.hist(x,20, histtype='bar', stacked=True)
plt.legend(['Gentoo'])
plt.title("bill_depth_mm for Gentoo Species")
plt.xlabel("bill_depth_mm")
plt.ylabel("Count")
plt.savefig('Images/bill_depth_mm_Gentoo.png')# Save to PNG file
plt.show()

# We can tell from the distribution on the bill depth that the distribution is not normal for the Gentoo species of penguin. i.e. it is not symetrical or in a 
# bell curve shape.

# %% [markdown]
# The histogram for bill depth is multimodal. A multimodal distribution is a probability distribution with more than one mode or peak in the data.
#
# The Gamma Distribution is a Continuous Probability Distribution that is widely used in different fields of science to model continuous variables that are always positive and have skewed distributions so I think it can be used for bill depth also.
#
# It looks like we have two Gamma distributions in the histogram above, so two probability distributions for the one variable bill depth.

# %%
 
# Using gamma() method 
gfg = np.random.gamma(3, 20, 100) 

print (gfg)
  
count, bins, ignored = plt.hist(gfg, 10, density = True) 
plt.title('Gamma Distribution for Bill Depth mm')
plt.xlabel("bill_depth_mm")
plt.ylabel("Count")
plt.show()
# Out:
# [ 56.2214064  101.21589971  37.17948627  19.84041095  39.62068796
#   93.52128615  51.39560686  54.33760691  69.9706617   27.75916138
#   43.5421863   41.84762627  51.8594719  112.81922294  68.21362932
#   20.40392025  31.71674344   7.48905941  31.97884085 134.36188293
#   57.42682319  62.28550574  61.65447291  34.80675597 200.91863762
#   90.06362476  38.21492518  40.44791469 150.35055876  73.8338477
#   50.94003756  74.28909358  74.89186203  61.75390518  45.61867169
#   51.60159208  75.32395656  66.66968124  39.44958119  64.78191544
#  102.81444356  55.11277675  80.72894753  62.49176994  43.128485
#   80.81578547  35.70464464  60.23471873  93.23647215  51.3165219
#   61.47251329  47.39551867  27.55043362  37.53474969  39.36511866
#   34.00108619  45.90849228 144.36915208  43.59080246  47.83702539
#   35.66504799  48.75570667  68.28057689 138.68565692  24.71383383
#  148.10463784  19.98757406  37.12783501  80.66705154  31.61145625
# ...

# %% [markdown]
# The next variable that I will look at is flipper_length_mm. To see what the distribution of flipper length is accross the Penguins dataset I will create a histogram for the female species.

# %%
#flipper_length_mm - Histogram - see if the distribution is normal

plt.figure(figsize = (10, 5))
x = [penguins.flipper_length_mm[penguins.sex==sp_name] for sp_name in ['FEMALE']]
plt.hist(x,15, histtype='bar', stacked=True)
plt.legend(['Female Species'])
plt.title("flipper_length_mm")
plt.xlabel("flipper_length_mm")
plt.ylabel("Count")
plt.savefig('Images/flipper_length_mm_Female.png')# Save to PNG file
plt.show()

# We can tell from the distribution on the bill depth that the distribution for the flipper_length_mm for the Female
# species  is close to a normal distribution 
# From the graph below I can see it is in a bell curve shape- There looks to be two normal distributions on the on histogram
# A normal distribution is typically in the shape of a bell curve

# %% [markdown]
# The probability distribution that I would use for flipper length would be np.random.normal. The paremeters are mean, standard deviation and size.

# %%
# import numpy and use the probability function of np.random.normal
import numpy as np 
import matplotlib.pyplot as plt

  
# Generating some random data 
# for an example 
data = np.random.normal(170, 220, 300) 
  
# Plotting the histogram. 
plt.hist(data, bins=15, density=True, alpha=0.6, color='b') 
plt.title('Normal Distribution - Flipper Length - Female Species')
plt.xlabel("flipper_length_mm")
plt.ylabel("Probability Density")
  
plt.show()

# %% [markdown]
# The next and last variable that I will look at is the body mass in grams of the penguin. Again this variable is a positive integer. I will graph the data on a histogram to see what the distribution looks like and try to replicate that with a numpy.random distribution type that matches. I will analyse the data for all the penguins on 'Dream Island'.

# %%
#body_mass_g - Histogram - see if the distribution is normal

plt.figure(figsize = (10, 5))
x = [penguins.body_mass_g[penguins.island==sp_name] for sp_name in ['Dream']] 
plt.hist(x,15, histtype='bar', stacked=True)
plt.legend(['All species on Dream Island'])
plt.title("body_mass_g for Penguins on Dream Island")
plt.xlabel("body_mass_g")
plt.ylabel("Count")
plt.savefig('Images/body_mass_g.png')# Save to PNG file
plt.show()

# We can tell from the distribution on the flipper length for all the species on 
# Dream island  is close to a normal distribution 
# From the graph below I can see it is in a bell curve shape-

# %% [markdown]
# I would like to see the spread of the data for the body mass so I will create a summary table in python using the describe() function

# %%
df = pd.DataFrame(penguins)

print(df.describe())
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# The probability distribution that I would use for body mass would be np.random.normal. The paremeters are mean, standard deviation and size. I have used the mean and standard deviation for all penguins. See below.

# %%
# import numpy and use the probability function of np.random.normal

  
# Generating some random data 
# for an example 
data = np.random.normal(4201, 801, 300) 

print (data)
  
# Plotting the histogram. 
plt.hist(data, bins=15, density=True, alpha=0.6, color='b') 
plt.title('Probability Distribution for Body Mass Penguins')
plt.ylabel('Probability Density')
plt.xlabel('Body Mass (g)')
  
plt.show()
# Out:
# [3376.1682434  4773.48254083 4817.35000037 5963.13701263 3213.03033267
#  4609.39869937 4781.46334423 4404.37392938 4794.31410978 5185.24348528
#  5369.08153383 3600.95988227 3732.38358769 2937.00745068 4191.53225402
#  2817.87166699 3949.50765507 3702.64114413 3326.90494323 4919.13736205
#  4900.41148661 3680.72803255 4465.69762455 4290.43511348 2329.19228547
#  4058.44134873 3476.6030913  4303.72442601 4001.40902477 4226.03177496
#  3991.95926469 5189.23263605 4480.19016172 3788.46438851 3982.75049975
#  4647.16955991 3601.98886069 4213.42684612 4954.62570418 3585.01147488
#  4596.98161822 3987.78368473 4004.90078542 4606.16624613 4994.5364957
#  2964.38020739 4092.63810675 3849.76671679 4566.8282856  3624.90975155
#  2493.36664907 4278.99272537 5214.04706953 3510.67373562 2916.0609509
#  3849.84781705 4547.16070895 4542.113468   3980.0172951  4902.64084668
#  3786.32741956 5033.77329083 5058.325066   5325.9819773  4388.87056763
# ...

# %% [markdown]
# ### Conclusion Task 3
#
#  Species, Island and Sex - np.random.choice
#
#  bill_length_mm - np.random.gamma
#
#  bill_depth_mm - np.random.gamma
#
#  flipper_length_mm - np.random.normal
#
#  body_mass_g - np.random.normal

# %% [markdown]
# ### End Task 3
#
# Task 3 - References
#
# https://docs.oracle.com/cd/E12825_01/epm.111/cb_user/frameset.htm?apas03.html
#
# https://www.simplilearn.com/tutorials/statistics-tutorial/what-is-probability-distribution#:~:text=A%20probability%20distribution%20is%20a,variable%20within%20a%20given%20range.
#
# https://bolt.mph.ufl.edu/6050-6052/unit-1/one-categorical-variable/#:~:text=In%20order%20to%20summarize%20the,converting%20the%20counts%20to%20percentages
#
# https://www.statology.org/frequency-tables-python/
#
# https://www.geeksforgeeks.org/how-to-create-frequency-tables-in-python/
#
# https://www.kristakingmath.com/blog/symmetric-and-skewed-distributions
#
# https://www.mygreatlearning.com/blog/gamma-distribution/#:~:text=Gamma%20Distribution%20is%20a%20Continuous,times%20between%20events%20are%20relevant.
#
# https://en.wikipedia.org/wiki/Gamma_distribution
#
# https://www.geeksforgeeks.org/python-numpy-np-lognormal-method/
#
# https://github.com/AudeAllen/Fundamentals-of-Data-Analysis---Tasks-and-Project/blob/main/tasks.ipynb

# %% [markdown]
# ### Task 4
#
# Suppose you are flipping two coins, each with a probability p of giving heads. Plot the entropy of the total number of heads versus p.
#
# ### Firstly what is entrophy?
#
# Entrophy is the degree of disorder or uncertainty in a system. In information theory, the entropy of a random variable is the average level of "information", "surprise", or "uncertainty" inherent to the variable's possible outcomes.
#
# The formula for entropy is
#
# ![image.png](attachment:image.png)
#
# The concept of information entropy was introduced by Claude Shannon in his 1948 paper "A Mathematical Theory of Communication", and is also referred to as Shannon entropy.
#
# Entrophy is the certainty or uncertainty that you are going to get the result you want.
#
# ### One Coin toss and Entrophy
#
# The probability of of one fair coin toss and getting heads is
#
# P = (number of desired outcomes) / (number of possible outcomes)
# P = 1/2 for heads
#
# So the probability of producing a head in a single fair coin toss is 0.5 - Outcome is Heads/Tails
#
# The entrophy of a single coin toss is 1. Each toss of the coin delivers no new information as the outcome of each coin toss is always certain.
#
# So say we have two coins what are the possible outcomes firstly.
#
# HH TT HT TH - There are 4 possible outcomes but only 3 are favourable. Meaning there are only 3 possible outcomes where the coin toss will produce a head.
#
# P = favorable outcomes / total outcomes
# P (at least one H) = 3/4 or 0.75
#
# 0.75 is the probability of getting one head with two coins.

# %%
# Here I am going to show that the entropy of a coin toss is 50/50 or 0.5/0.5 - See below.
# So the entrophy of a coin toss is 1
# the entropy of a fair coin toss is 1 bit:

import numpy as np
from scipy.stats import entropy
coin_toss = [0.5, 0.5]
entropy(coin_toss, base=2)

# Conclusion 
# The entropy of a fair coin toss is 1 bit:
# Out:
# 1.0

# %% [markdown]
# ### Entrophy on flipping two coins
#
# Two bits of entropy: In the case of two fair coin tosses, the information entropy in bits is the base-2 logarithm of the number of possible outcomes; with two coins there are four possible outcomes, and two bits of entropy. Generally, information entropy is the average amount of information conveyed by an event, when considering all possible outcomes.

# %%
import numpy as np
from scipy.stats import entropy
coin_toss = [0.75, 0.25]
entropy(coin_toss, base=2)

# The entrophy of a two coin toss is 0.8112781244591328 beacuse there is a .75 chance that we will get a head if we toss the 
# two coins HH TH HT and .25 is TT
# Out:
# 0.8112781244591328

# %%
# Or entrophy can be calculated as such

# Entropy.

import numpy as np
def H(p):
  return -(1 - p) * np.log2(1.0 - p) - p * np.log2(p)

# %%
# Entropy of 0.75.
H(0.75)

# We are getting the same entrophy value as above which is 0.8112781244591328
# Out:
# 0.8112781244591328

# %%
# Create an empty plot.
#import matplotlib as plt
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(8,6))

# p is a probability.
# p = np.linspace(0.00000001, 0.99999999, 10001)
p = np.linspace(0.00000001, 0.99999999, 10001)

# Plot H(p).
ax.plot(p, H(p));

x_data = [0.75]
y_data = [0.8112781244591328]

plt.scatter(x_data, y_data, c='red')

for x, y in zip(x_data, y_data):
    plt.axvline(x=x, color='r', linestyle='-')
    plt.axhline(y=y, color='r', linestyle='-')


    # Plot H(p).
    ax.plot(p, H(p));

plt.xlabel('p - probability of heads (of a two coin flip)')
plt.ylabel('Entropy H(p):  [0, 1]')

plt.title('Entropy of the total number of heads versus p')
# Out:
# Text(0.5, 1.0, 'Entropy of the total number of heads versus p')

# %%
from scipy.stats import entropy
import matplotlib.pyplot as plt
p = [0.75, 0.25]
e = entropy(p, base=2)
print(e)
# Out:
# 0.8112781244591328

# %% [markdown]
# ### End Task 4
#
# Task 4 - References
#
# https://www.merriam-webster.com/dictionary/entropy#:~:text=broadly%20%3A%20the%20degree%20of%20disorder,universe%20toward%20death%20and%20disorder
#
# https://en.wikipedia.org/wiki/Entropy_(information_theory)
#
# https://sciencenotes.org/coin-toss-probability-formula-and-examples/
#
# https://www.blog.trainindata.com/mutual-information-with-python/
#
# https://en.wikipedia.org/wiki/Entropy_(information_theory)#:~:text=Two%20bits%20of%20entropy%3A%20In,and%20two%20bits%20of%20entropy
#
# https://towardsdatascience.com/entropy-in-soft-actor-critic-part-1-92c2cd3a3515

# %% [markdown]
# ### Task 5
#
# Create an appropriate individual plot for each of the variables in
# the penguin data set
#
# ![image.png](attachment:image.png)
#
# The Penguins dataset was collected between 2007–2009 by Dr. Kristen Gorman with the Palmer Station Long Term Ecological Research Program, part of the US Long Term Ecological Research Network.
#
# The palmerpenguins data contains size measurements for three penguin species observed on three islands in the Palmer Archipelago, Antarctica. The Penguins dataset has 7 columns and 344 rows. Of the 7 columns 3 are categorical (species, island, sex) and the rest are numeric (bill_length_mm	bill_depth_mm	flipper_length_mm	body_mass_g).
#
# ### Description of Columns in Penguins Dataset
# 1. species - Field denoting the penguin speecies(Adelie, Gentoo, and Chinstrap)
# 2. island - Field denoting the island in Palmer Archipelago
# 3. bill_length_mm - a number denoting the bill length of the penguin in millimeters
# 4. bill_depth_mm - a number denoting the bill depth of the penguin in millimeters
# 5. flipper_length_mm - a number denoting the flipper length of the penguin in millimeters
# 6. body_mass_g - a number denoting body mass in grams
# 7. sex - Field denoting penguin sex (female, male)
#
# ### Type of Variable
#
# 1. species - categorical
# 2. island -  categorical
# 3. bill_length_mm - numerical
# 4. bill_depth_mm - numerical
# 5. flipper_length_mm - numerical
# 6. body_mass_g - numerical
# 7. sex - categorical
#
# I will go through each variable and create the most appropriate plot for that particular variable.

# %% [markdown]
# ### 1. species - categorical
#
# The species variable is a categorical variable  denoting the penguin species(Adelie, Gentoo, and Chinstrap).
#
# For this variable I think a count plot would be the best visual plot to see the numbers of each species in the dataset.
#
# I will do this using the python data visualization library, Seaborn.

# %%
# Firstly I want to check what variables in the Penguins dataset have null values

# Read in CSV file and using the function isnull() and sum it gives me the total null values for each variable.

penguins  = pd.read_csv('Data/penguins.csv') 

penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
## I can visualise the null values in a bar chart
## Both Species and Island are the only two variables who have no null values

df.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Firstly I will import the penguins dataset in .csv format
# I have also imported the python module 'seaborn' and matplotlib.pyplot as plt

import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
  

# Read in CSV file

penguins  = pd.read_csv('Data/penguins.csv')

ax = sns.countplot(x='species',  data=df)
plt.legend(['All Species'])
plt.title('Frequency of Three Species')
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# As well as the count plot through Seaborn I can also visualise the categorical species variable by a pie plot.

# %%
## Another plot that would show the frequency of the species variable would be a pie plot

penguins  = pd.read_csv('Data/penguins.csv')

penguins=penguins.species.value_counts()
penguins.plot(kind='pie',autopct="%.2f%%")
plt.title('Frequency of Penguin Species')
# Out:
# Text(0.5, 1.0, 'Frequency of Penguin Species')

# %% [markdown]
# ### Result - Countplot and pie plot for variable species
#
# We can see from the countplot and pie plot visualisations that the Adelie species occurs the most frequently in the dataset, then the Gentoo species and the Chinstrap species occurs the least frequently in the Penguins dataset.
#
# I can also output percentages in each slice of the pie so that it is clear what species occurs most and least frequently in the Penguins dataset.

# %% [markdown]
# ### 2. Island - categorical
#
# The island variable is a categorical variable in the Penguins dataset denoting the island that the penguin was found on(Torgersen, Biscoe, and Dream).
#
# For this variable I think a count plot would be the best visual plot to see the numbers of each island in the dataset.
#
# I will do this using the python data visualization library, Seaborn.

# %%
# Firstly I will import the penguins dataset in .csv format
# I have also imported the python module 'seaborn' and matplotlib.pyplot as plt
# I do not have to do this as it is imported previously 

import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
  

penguins  = pd.read_csv('Data/penguins.csv')

ax = sns.countplot(x='island',  data=df)
plt.legend(['All Islands'])
plt.title('Frequency of Three Islands')
for container in ax.containers:
    ax.bar_label(container)

# %%
## Another plot that would show the frequency of the island variable would be a pie plot

penguins  = pd.read_csv('Data/penguins.csv')

penguins=penguins.island.value_counts()
plt.title('Frequency of Three Islands')
penguins.plot(kind='pie',autopct="%.2f%%")
# Out:
# <Axes: title={'center': 'Frequency of Three Islands'}, ylabel='island'>

# %% [markdown]
# ### Result - Countplot and Pie Plot for variable island
#
# We can see from the countplot and pie plot visualisations that the Biscoe island occurs the most frequently in the dataset, then the Dream island and the Torgersen island occurs the least frequently in the Penguins dataset.

# %% [markdown]
# ### 3. Sex - categorical
#
# The sex variable is a categorical variable in the Penguins dataset denoting the gender of each penguin (Male, Female).
#
# For this variable I think a count plot would be the best visual plot to see the numbers of each sex of penguin in the dataset.
#
# I will do this using the python data visualization library, Seaborn.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

penguins  = pd.read_csv('Data/penguins.csv')

ax = sns.countplot(x='sex',  data=df)

plt.title('Frequency of Gender')
for container in ax.containers:
    ax.bar_label(container)

# %%
## Another plot that would show the frequency of the sex variable would be a pie plot

penguins  = pd.read_csv('Data/penguins.csv')

penguins=penguins.sex.value_counts()
plt.title('Frequency of Gender')
penguins.plot(kind='pie',autopct="%.2f%%")
# Out:
# <Axes: title={'center': 'Frequency of Gender'}, ylabel='sex'>

# %% [markdown]
# ### Result - Countplot and Pie Plot for variable sex
#
# We can see from the countplot and pie plot visualisations that there are slightly more male penguins than female penguins in the Penguins dataset.

# %% [markdown]
# ### 4. bill_length_mm - Numerical Continuous Variable
#
# In order to visualise the bill_length_mm I would choose a histogram. A histogram is a great visual tool for numerical data. It shows the frequency of that data. Each bar in the histogram represents the count of data points in each group. Histograms can show patterns and trends within a dataset. We can see the distribution of the data. Is it normal or uniform distribution or does it follow another distribution.
#
# A density plot (also known as kernel density plot) is another visualization tool for evaluating data distributions. It can be considered as a smoothed histogram. The peaks of a density plot help display where values are concentrated over the interval. There are a variety of smoothing techniques. Kernel Density Estimation (KDE) is one of the techniques used to smooth a histogram.
#
# Below I am going to import seaborn and plot a histogram with a density plot.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
 
# Load dataset
penguins  = pd.read_csv('Data/penguins.csv')
 
# Plot histogram
plt.title('Bill Length using (mm) using Histogram')
sns.histplot(data = penguins, x = "bill_length_mm", kde = True)
# Out:
# <Axes: title={'center': 'Bill Length using (mm) using Histogram'}, xlabel='bill_length_mm', ylabel='Count'>

# %% [markdown]
# ### Result - Histogram variable bill_length_mm
#
# Based on the summary below, there is variation among the penguins. It can be seen that their bills varies from 32.10 mm to 59.50 mm, with an average being 43.92 mm and a standard deviation of 5.46.
#
# This can be seen in the histogram also. We can see the distribution is close to normal. The shape is similar to a bell curve. In fact it is like there are two normal distributions. (Two bell curves in the histogram)

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ### 5. bill_depth_mm - Numerical Continuous Variable
#
# As this is the same type of variable as bill_length_mm I am going to use a histogram with Kernel Density Estimation. (KDE)

# %%
 
# Plot histogram for bill_depth_mm
plt.title('Bill Depth using (mm) using Histogram')
sns.histplot(data = penguins, x = "bill_depth_mm", kde = True)
# Out:
# <Axes: title={'center': 'Bill Depth using (mm) using Histogram'}, xlabel='bill_depth_mm', ylabel='Count'>

# %% [markdown]
# ### Result - Histogram variable bill_depth_mm
#
# Based on the summary above, there is variation among the penguins. It can be seen that their bill depth varies from 13.10 mm to 21.50 mm, with an average being 17.15 mm and a standard deviation of 1.97.
#
# This can be seen in the histogram also. We can see the distribution is close to normal. The shape is similar to a bell curve.

# %% [markdown]
# ### 4. flipper_length_mm - Numerical Continuous Variable
#
# Again I am going to use a histogram to visualise this variable with  Kernel Density Estimation. (KDE)

# %%
# Plot histogram for flipper_length_mm
plt.title('Flipper Length using (mm) using Histogram')
sns.histplot(data = penguins, x = "flipper_length_mm", kde = True)
# Out:
# <Axes: title={'center': 'Flipper Length using (mm) using Histogram'}, xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ### Result - Histogram variable flipper_length_mm
#
# Based on the summary above, there is variation among the penguins. It can be seen that their flipper length varies from 172 mm to 231 mm, with an average being 200.92 mm and a standard deviation of 14.06.
#
# This can be seen in the histogram also. We can see the distribution is close to normal. The shape is similar to a bell curve. The distribution looks similar to th distribution of bill_length_mm. Two normal distributions for this variable.

# %% [markdown]
# ### 6. body_mass_g - Numerical Continuous Variable -
#
# This variable is measured in grams not mm like the previous continuous variables.  It can still be shown visually in histogram format to see the distribution of this one variable.

# %%
# Plot histogram for body_mass_g
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data = penguins, x = "body_mass_g", kde = True)
plt.title("Penguins Body Mass (Grams)", size=15, color="blue")
# Out:
# Text(0.5, 1.0, 'Penguins Body Mass (Grams)')

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ### Result - Histogram variable body_mass_g
#
# Based on the summary above, there is variation among the penguins. It can be seen that their body mass varies from 2700g to 6300g, with an average being 4201.75g  and a standard deviation of 801.95.
#
# The histogram shows a right-skewed distribution. This indicates that the majority of the data is located on the left side of the graph, and the mean, or average, is greater than the median.

# %% [markdown]
# I have shown how to visualise each individual variable within the Pengunis dataset. Of course there are multiple ways in which we can visualise and show the relationship between variables on a dataset. I will go though some of the options.
#
# The box plot is used to compare the distribution of numerical data between levels of a categorical variable. Let’s see the distribution of flipper length by species.  A boxplot also gives a visual indication of how a data set's 25th percentile, 50th percentile, 75th percentile, minimum, maximum and outlier values are spread out and compare to each other.
#
# Again I can do this visualisation through the python visualisation package 'Seaborn'.
#
# What is useful about boxplots is that as well as the centiles we can see if there are any outliers present in the dataset for a particular categorical variable.

# %%
sns.boxplot(x = "species", y = "bill_length_mm", data =penguins)
plt.title("Bill Length for 3 Penguin Species", size=15, color="Blue")
# Out:
# Text(0.5, 1.0, 'Bill Length for 3 Penguin Species')

# %% [markdown]
# ### Result - Boxplot Variable bill_length_mm
#
# Without knowing much about boxplots or the Penguins dataset I can see that the Adelie species differs in bill length from the other two species, Chinstrap and Gentoo. The bill length of the Adelie looks significantly shorter than that of the other two species.

# %%
sns.boxplot(x = "species", y = "bill_depth_mm", data =penguins)
plt.title("Bill Depth for 3 Penguin Species", size=15, color="blue")
# Out:
# Text(0.5, 1.0, 'Bill Depth for 3 Penguin Species')

# %% [markdown]
# ### Result - Boxplot Variable bill_depth_mm
#
# From analysing the boxplot I can see that the bill depth of the Gentoo species differs from Adelie and Chinstrap species. The bill depth is not as deep for the Gentoo species.

# %% [markdown]
# ### Result - Boxplot Variable body_mass_g
#
# From the boxplot below it gives us a good visualisation of which species is the heaviest out of all 3. The Gentoo looks to be the heaviest by some margin. The two triangular dots on the outside of the Chinstrap species shows that there are two outliers for this species in body mass.

# %%
sns.boxplot(x = "species", y = "body_mass_g", data =penguins)
plt.title("Body Mass for 3 Penguin Species", size=15, color="blue")
# Out:
# Text(0.5, 1.0, 'Body Mass for 3 Penguin Species')

# %% [markdown]
# ### End Task 5
#
# Task 5 - References
#
# https://stackoverflow.com/questions/63687789/how-do-i-create-a-pie-chart-using-categorical-data-in-matplotlib
#
# https://stackoverflow.com/questions/55104819/display-count-on-top-of-seaborn-barplot
#
# https://www.kaggle.com/code/parulpandey/penguin-dataset-the-new-iris
#
# https://www.jaspersoft.com/articles/what-is-a-histogram-chart
#
# https://www.geeksforgeeks.org/how-to-make-histograms-with-density-plots-with-seaborn-histplot/
#
# https://study.com/academy/lesson/skewed-distribution-examples-definition-quiz.html#:~:text=Right%2Dskewed%20distributions%20indicate%20that,is%20greater%20than%20the%20median
#
# https://www.kaggle.com/code/tirendazacademy/penguin-dataset-data-visualization-with-seaborn
